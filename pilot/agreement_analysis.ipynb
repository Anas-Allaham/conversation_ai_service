# %% [markdown]
# # Oral placement pilot agreement analysis
# Fill the two CSV templates first. The script calculates human agreement, Cohen's kappa, system exact/adjacent agreement, dimension disagreements, and duration.

# %%
# %run ../tools/analyze_pilot.py

# %%
import json
from pathlib import Path

results = json.loads(Path('agreement_results.json').read_text())
results
